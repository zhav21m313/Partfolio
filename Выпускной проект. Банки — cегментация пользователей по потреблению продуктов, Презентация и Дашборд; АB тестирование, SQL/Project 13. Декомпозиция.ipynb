# %% [markdown]
# # Анализ клиентов банка

# %% [markdown]
# **Постановка задачи проекта:**
# * Проанализировать клиентов регионального банка и сегментировать пользователей по количеству потребляемых продуктов, обращая особое внимание на отток

# %% [markdown]
# **Описание проекта**
# * Заказчик - тимлид
# * Информация нужна тимлиду, который работает в банковской сфере
# * Хотят получить следующие данные: готовый анализ клиентов регионального банка и сегментацию пользователей по количеству потребляемых продуктов
# * Основная цель аналитики - снизить отток, выделение сегментов же нам нужно для формирования более релевантных предложений, которые помогут удержать клиента

# %% [markdown]
# **Постановка плана работы:**
# * Открыть файл и изученить общую информацию
#     * проверка на наличие пропусков; исследование типов данных
# * Выполнить предобработку данных
#     * приведение к нужному стилю написания колонок
#     * поиск явных  и неявных дубликатов
#     * заполнение пропущенных данных
#     * приведение cтолбцов к нужному типу данных
#     * проверка на выбросы
# * Провести исследовательский анализ данных
#     * сравнение портретов типичных клиентов
#     * распределение непрерывных(в том числе в разрезе оттока)
# * Сформулировать и проверить статистические гипотезы
#     * выдвинуть две гипотезы( для каждой составить нулевую(H0) и альтернативную(H) гипотезы)
#     * отследить применимость того или иного статистического критерия( в данном случае возможна предварительная проверка на нормальность)
#     * подтвердить/опровергнуть ту или иную гипотезу
#     * в данном случае проверим следующие гипотезы:
#        1) Проверка гипотезы различия возраста между теми клиентами, которые  ушли, и теми, которые остались
#           * H0: различия нет между теми, кто ушёл, и теми, кто остался(различия не имеют статистической значимости)
#           * H: различия есть между теми, кто ушёл, и теми, кто остался(различия статистически значимы)
#        2) Проверка гипотезы различия баланса между теми клиентами, у которых есть кредитная карта и теми, у которых её нет
#           * H0: различия нет между теми клиентами, у которых есть кредитная карта и теми, у которых её нет(различия не имеют статистической значимости)
#           * H: различия есть между теми клиентами, у которых есть кредитная карта и теми, у которых её нет(различия статистически значимы)
# * Сегментировать пользователей на основе данных о количестве потребляемых продуктов
#     * проанализировать количество потребляемых продуктов пользователями
#     * разделить пользователей на отдельные сегменты
#     * посчитать отток и размер сегментов
#     * приоритезировать сегменты( количество сегментов должно быть 5-6)
# * Сделать общий вывод и рекомендацию для заказчика
#     * дать конкретные рекомендации по приоритетным сегментам
# * Составить дашборд для заказчика
# * Составить презентацию для заказчика в соответствии с планом:
#     * Введение
#     * Постановка целей и задач
#     * Продемонстрировать портрет пользователей
#     * Продемонстрировать сегментацию пользователей
#     * Демонстрация и проверка выдвинутых гипотез
#     * Сделать общий вывод и дать рекомендацию заказчику

# %% [markdown]
# <div class="alert alert-info">
# Проверка на выбросы будет проводиться на этапе "Предобработка данных".Добавил изменения в "Предобработку данных"👍
# </div>

# %% [markdown]
# **Описание данных:**
# * user_id — идентификатор пользователя
# * score — баллы кредитного скоринга
# * сity — город
# * gender — пол
# * age — возраст
# * equity — количество объектов в собственности
# * balance — баланс на счёте
# * products — количество продуктов, которыми пользуется клиент
# * credit_card — есть ли кредитная карта
# * loyalty — активный клиент
# * estimated_salary — заработная плата клиента
# * churn — ушёл или нет
